# %%
import pandas as pd
import glob

# %%
path = 'res_gossiping'
data = list()
for articlePath in glob.glob(path + '/*.txt'):
    with open(articlePath, 'r', encoding='utf-8') as f:
        data.append(f.read().split('---split---')[1].split('\n')[1:-1])
data
# Out:
# [['推: 13',
#   '噓: 4',
#   '分數: 9',
#   '作者: sonyoung (youngson)',
#   '標題: [問卦] 在都是女生的環境工作是不是要小心',
#   '時間: Sat Feb  6 03:21:39 2021'],
#  ['推: 8',
#   '噓: 8',
#   '分數: 0',
#   '作者: ivonie5566 (強烈譴責趙又廷抄襲5566)',
#   '標題: [問卦] 愛莉莎莎絕美照曝光 網驚：上海灘賭聖？',
#   '時間: Fri Feb  5 22:37:39 2021'],
#  ['推: 12',
#   '噓: 0',
#   '分數: 12',
#   '作者: aivxg (家裡窮西索XD)',
#   '標題: [問卦] 其實雞排妹是防疫大使吧',
#   '時間: Fri Feb  5 22:24:40 2021'],
#  ['推: 2',
#   '噓: 1',
#   '分數: 1',
#   '作者: ocean1025 (人生海海)',
#   '標題: [問卦]關於 電影第六感生死緣',
#   '時間: Sat Feb  6 00:48:51 2021'],
#  ['推: 2',
#   '噓: 2',
#   '分數: 0',
#   '作者: rd5186 (GIOS)',
#   '標題: [問卦] 按照這個情勢，翁立友是不是還可以出這招',
#   '時間: Fri Feb  5 22:49:34 2021'],
#  ['推: 13',
#   '噓: 0',
#   '分數: 13',
#   '作者: magic543 (何布)',
#   '標題: [問卦] 罷免案的討論度是不是被雞排妹吸走了',
#   '時間: Fri Feb  5 23:16:14 2021'],
#  ['推: 5',
#   '噓: 0',
#   '分數: 5',
#   '作者: juicypussy (多汁小貓咪)',
#   '標題: [問卦] 什麼時候會脫口說出「垃圾」',
#   '時間: Sat Feb  6 03:48:30 2021'],
#  ['推: 5',
#   '噓: 6',
#   '分數: -1',
# ...

# %%
columns = [c.split(': ')[0] for c in data[0]]
columns
# Out:
# ['推', '噓', '分數', '作者', '標題', '時間']

# %%
df = pd.DataFrame(data=data, columns=columns)
df
# Out:
#           推      噓       分數                              作者  \
# 0     推: 13   噓: 4    分數: 9         作者: sonyoung (youngson)
# 1      推: 8   噓: 8    分數: 0  作者: ivonie5566 (強烈譴責趙又廷抄襲5566)
# 2     推: 12   噓: 0   分數: 12             作者: aivxg (家裡窮西索XD)
# 3      推: 2   噓: 1    分數: 1            作者: ocean1025 (人生海海)
# 4      推: 2   噓: 2    分數: 0               作者: rd5186 (GIOS)
# ..      ...    ...      ...                             ...
# 492    推: 3   噓: 0    分數: 3              作者: yaotz5065 (咿喔)
# 493    推: 3   噓: 0    分數: 3         作者: Qorqios (雲☁傲嬌銀長直JK)
# 494   推: 47  噓: 12   分數: 35           作者: JRSmith (我兩冠你們幾冠)
# 495    推: 9   噓: 0    分數: 9              作者: f22313467 (軍曹)
# 496  推: 516  噓: 14  分數: 502          作者: ghost90331 (蘭陽金城武)
#
#                                標題                            時間
# 0       標題: [問卦] 在都是女生的環境工作是不是要小心  時間: Sat Feb  6 03:21:39 2021
# 1    標題: [問卦] 愛莉莎莎絕美照曝光 網驚：上海灘賭聖？  時間: Fri Feb  5 22:37:39 2021
# ...

# %%
def columnFilter(s):
    output = s.split(': ')[1]
    return output

# %%
df['推'].apply(columnFilter)
# Out:
# 0       13
# 1        8
# 2       12
# 3        2
# 4        2
#       ...
# 492      3
# 493      3
# 494     47
# 495      9
# 496    516
# Name: 推, Length: 497, dtype: object

# %%
df2 = df.copy()
df2
# Out:
#           推      噓       分數                              作者  \
# 0     推: 13   噓: 4    分數: 9         作者: sonyoung (youngson)
# 1      推: 8   噓: 8    分數: 0  作者: ivonie5566 (強烈譴責趙又廷抄襲5566)
# 2     推: 12   噓: 0   分數: 12             作者: aivxg (家裡窮西索XD)
# 3      推: 2   噓: 1    分數: 1            作者: ocean1025 (人生海海)
# 4      推: 2   噓: 2    分數: 0               作者: rd5186 (GIOS)
# ..      ...    ...      ...                             ...
# 492    推: 3   噓: 0    分數: 3              作者: yaotz5065 (咿喔)
# 493    推: 3   噓: 0    分數: 3         作者: Qorqios (雲☁傲嬌銀長直JK)
# 494   推: 47  噓: 12   分數: 35           作者: JRSmith (我兩冠你們幾冠)
# 495    推: 9   噓: 0    分數: 9              作者: f22313467 (軍曹)
# 496  推: 516  噓: 14  分數: 502          作者: ghost90331 (蘭陽金城武)
#
#                                標題                            時間
# 0       標題: [問卦] 在都是女生的環境工作是不是要小心  時間: Sat Feb  6 03:21:39 2021
# 1    標題: [問卦] 愛莉莎莎絕美照曝光 網驚：上海灘賭聖？  時間: Fri Feb  5 22:37:39 2021
# ...

# %%
for c in df:
    print(c)
# Out:
# 推
# 噓
# 分數
# 作者
# 標題
# 時間

# %%
for c in df:
    df[c] = df[c].apply(columnFilter)
df
# Out:
#        推   噓   分數                          作者                        標題  \
# 0     13   4    9         sonyoung (youngson)     [問卦] 在都是女生的環境工作是不是要小心
# 1      8   8    0  ivonie5566 (強烈譴責趙又廷抄襲5566)  [問卦] 愛莉莎莎絕美照曝光 網驚：上海灘賭聖？
# 2     12   0   12             aivxg (家裡窮西索XD)          [問卦] 其實雞排妹是防疫大使吧
# 3      2   1    1            ocean1025 (人生海海)           [問卦]關於 電影第六感生死緣
# 4      2   2    0               rd5186 (GIOS)  [問卦] 按照這個情勢，翁立友是不是還可以出這招
# ..   ...  ..  ...                         ...                       ...
# 492    3   0    3              yaotz5065 (咿喔)  [問卦] 有沒有only you和警政時報的掛？
# 493    3   0    3         Qorqios (雲☁傲嬌銀長直JK)        [問卦] 半夜肚子會餓到雷鳴八卦嗎？
# 494   47  12   35           JRSmith (我兩冠你們幾冠)        [問卦] 雞排妹之前形象怎麼這麼好？
# 495    9   0    9              f22313467 (軍曹)      [問卦] 雞排妹事件是不是明天就沒人理了
# 496  516  14  502          ghost90331 (蘭陽金城武)             [問卦] 跟我說聲加油好嗎
#
#                            時間
# 0    Sat Feb  6 03:21:39 2021
# 1    Fri Feb  5 22:37:39 2021
# ...

# %%
for c in df2:
    df2[c] = df2[c].apply(lambda x: x.split(': ')[1])
df2
# Out:
#        推   噓   分數                          作者                        標題  \
# 0     13   4    9         sonyoung (youngson)     [問卦] 在都是女生的環境工作是不是要小心
# 1      8   8    0  ivonie5566 (強烈譴責趙又廷抄襲5566)  [問卦] 愛莉莎莎絕美照曝光 網驚：上海灘賭聖？
# 2     12   0   12             aivxg (家裡窮西索XD)          [問卦] 其實雞排妹是防疫大使吧
# 3      2   1    1            ocean1025 (人生海海)           [問卦]關於 電影第六感生死緣
# 4      2   2    0               rd5186 (GIOS)  [問卦] 按照這個情勢，翁立友是不是還可以出這招
# ..   ...  ..  ...                         ...                       ...
# 492    3   0    3              yaotz5065 (咿喔)  [問卦] 有沒有only you和警政時報的掛？
# 493    3   0    3         Qorqios (雲☁傲嬌銀長直JK)        [問卦] 半夜肚子會餓到雷鳴八卦嗎？
# 494   47  12   35           JRSmith (我兩冠你們幾冠)        [問卦] 雞排妹之前形象怎麼這麼好？
# 495    9   0    9              f22313467 (軍曹)      [問卦] 雞排妹事件是不是明天就沒人理了
# 496  516  14  502          ghost90331 (蘭陽金城武)             [問卦] 跟我說聲加油好嗎
#
#                            時間
# 0    Sat Feb  6 03:21:39 2021
# 1    Fri Feb  5 22:37:39 2021
# ...

# %%
df.to_csv('ptt.csv', index=False)

# %%
df.to_csv('ptt_without_header.csv', index=False, header=None)

# %%
df.to_csv('ptt_without_header.csv', index=False, header=None, encoding='utf-8-sig')

# %%
df3 = pd.read_csv('ptt_without_header.csv', header=None)
df3
# Out:
#        0   1    2                           3                         4  \
# 0     13   4    9         sonyoung (youngson)     [問卦] 在都是女生的環境工作是不是要小心
# 1      8   8    0  ivonie5566 (強烈譴責趙又廷抄襲5566)  [問卦] 愛莉莎莎絕美照曝光 網驚：上海灘賭聖？
# 2     12   0   12             aivxg (家裡窮西索XD)          [問卦] 其實雞排妹是防疫大使吧
# 3      2   1    1            ocean1025 (人生海海)           [問卦]關於 電影第六感生死緣
# 4      2   2    0               rd5186 (GIOS)  [問卦] 按照這個情勢，翁立友是不是還可以出這招
# ..   ...  ..  ...                         ...                       ...
# 492    3   0    3              yaotz5065 (咿喔)  [問卦] 有沒有only you和警政時報的掛？
# 493    3   0    3         Qorqios (雲☁傲嬌銀長直JK)        [問卦] 半夜肚子會餓到雷鳴八卦嗎？
# 494   47  12   35           JRSmith (我兩冠你們幾冠)        [問卦] 雞排妹之前形象怎麼這麼好？
# 495    9   0    9              f22313467 (軍曹)      [問卦] 雞排妹事件是不是明天就沒人理了
# 496  516  14  502          ghost90331 (蘭陽金城武)             [問卦] 跟我說聲加油好嗎
#
#                             5
# 0    Sat Feb  6 03:21:39 2021
# 1    Fri Feb  5 22:37:39 2021
# ...

# %%
df3.columns = columns
df3
# Out:
#        推   噓   分數                          作者                        標題  \
# 0     13   4    9         sonyoung (youngson)     [問卦] 在都是女生的環境工作是不是要小心
# 1      8   8    0  ivonie5566 (強烈譴責趙又廷抄襲5566)  [問卦] 愛莉莎莎絕美照曝光 網驚：上海灘賭聖？
# 2     12   0   12             aivxg (家裡窮西索XD)          [問卦] 其實雞排妹是防疫大使吧
# 3      2   1    1            ocean1025 (人生海海)           [問卦]關於 電影第六感生死緣
# 4      2   2    0               rd5186 (GIOS)  [問卦] 按照這個情勢，翁立友是不是還可以出這招
# ..   ...  ..  ...                         ...                       ...
# 492    3   0    3              yaotz5065 (咿喔)  [問卦] 有沒有only you和警政時報的掛？
# 493    3   0    3         Qorqios (雲☁傲嬌銀長直JK)        [問卦] 半夜肚子會餓到雷鳴八卦嗎？
# 494   47  12   35           JRSmith (我兩冠你們幾冠)        [問卦] 雞排妹之前形象怎麼這麼好？
# 495    9   0    9              f22313467 (軍曹)      [問卦] 雞排妹事件是不是明天就沒人理了
# 496  516  14  502          ghost90331 (蘭陽金城武)             [問卦] 跟我說聲加油好嗎
#
#                            時間
# 0    Sat Feb  6 03:21:39 2021
# 1    Fri Feb  5 22:37:39 2021
# ...
